# %% [markdown]
# <a href="https://colab.research.google.com/github/aviraltyagi/DeepLearningArchitectures/blob/main/ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Input, Add, Dense, Flatten, ZeroPadding2D, BatchNormalization, Conv2D, AveragePooling2D, MaxPool2D, GlobalMaxPool2D, Activation
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
import typing

# %%
class CustomLayer(Layer):
  def __init__(self, filter, kernelSize, stride, padding, name, kernelInitializer, axis= 3):
    super(CustomLayer, self).__init__()
    self.Conv = Conv2D(filters= filter, kernel_size= kernelSize, strides= stride, padding= padding, name= name + "conv", kernel_initializer= kernelInitializer)
    self.BatchNorm = BatchNormalization(axis = axis, name= name + "bn")
    self.Activation = Activation('relu')
    #self.n = name

  def call(self, input, training = False, isActivation = True):
    x = self.Conv(input, training = training)
    x = self.BatchNorm(x)
    #print(self.n + "_conv")
    if isActivation:
      x = self.Activation(x)
      #print(self.n + "_active")
    
    return x

# %%
class CustomBlock():
  def identity_Block(input, f, filters, stage, block):
    name_base = block + "S" + str(stage)

    F1, F2, F3 = filters

    x_shortcut = input

    # First Component of main path
    x = CustomLayer(filter= F1, kernelSize= (1,1), stride= (1,1), padding= 'valid', name= name_base + "_L1", kernelInitializer= glorot_uniform(seed= 0))(input, training = True)

    # Second Component of main path
    x = CustomLayer(filter= F2, kernelSize= (f,f), stride= (1,1), padding= 'same', name= name_base + "_L2", kernelInitializer= glorot_uniform(seed= 0))(x, training = True)

    # Third component of main path
    x = CustomLayer(filter= F3, kernelSize= (1,1), stride= (1,1), padding= 'valid', name= name_base + "_L3", kernelInitializer= glorot_uniform(seed= 0))(x, training = True, isActivation= False)

    # Final step: Add shortcut value to the main path
    x = Add()([x, x_shortcut])
    x = Activation('relu')(x, training= True)

    return x

  def convolutional_Block(input, f, filters, stage, block, s= 2):
    name_base = block + "S" + str(stage)

    F1, F2, F3 = filters

    x_shortcut = input

    # First Component of main path
    x = CustomLayer(filter= F1, kernelSize= (1,1), stride= (s,s), padding= 'valid', name= name_base + "_L1", kernelInitializer= glorot_uniform(seed= 0))(input, training = True)

    # Second Component of main path
    x = CustomLayer(filter= F2, kernelSize= (f,f), stride= (1,1), padding= 'same', name= name_base + "_L2", kernelInitializer= glorot_uniform(seed= 0))(x, training = True)

    # Third component of main path
    x = CustomLayer(filter= F3, kernelSize= (1,1), stride= (1,1), padding= 'valid', name= name_base + "_L3", kernelInitializer= glorot_uniform(seed= 0))(x, training = True, isActivation= False)

    # Shortcut path
    x_shortcut = Conv2D(filters= F3, kernel_size= (1,1), strides=(s,s), padding= 'valid', name= 'res' + name_base + '1', kernel_initializer= glorot_uniform(seed= 0))(x_shortcut)
    x_shortcut = BatchNormalization(axis= 3, name= 'bn' + name_base + '1')(x_shortcut)

    # Final step: Add shortcut value to the main path
    x = Add()([x, x_shortcut])
    x = Activation('relu')(x, training= True)

    return x

# %%
class CustomResNet(Model):
  def ResNet50(input_shape: typing.Tuple[int], classes: int) -> Model:
    x_input = Input(shape= input_shape)

    x = ZeroPadding2D(padding= (3,3))(x_input)

    # Stage 1
    x = CustomLayer(filter= 64, kernelSize= (7,7), stride= (2,2), padding= 'valid', name = 'S1_L1_', kernelInitializer= glorot_uniform(seed= 0))(x)
    x = MaxPool2D(pool_size= (3,3), strides= (2,2))(x)

    # Stage 2
    x = CustomBlock.convolutional_Block(input= x, f= 3, filters= [64, 64, 256], stage= 2, block= 'CB_', s= 1)
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [64, 64, 256], stage= 2, block= 'IB_1')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [64, 64, 256], stage= 2, block= 'IB_2')

    # Stage 3
    x = CustomBlock.convolutional_Block(input= x, f= 3, filters= [128, 128, 512], stage= 3, block= 'CB_', s= 2)
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [128, 128, 512], stage= 3, block= 'IB_1')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [128, 128, 512], stage= 3, block= 'IB_2')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [128, 128, 512], stage= 3, block= 'IB_3')

    # Stage 4
    x = CustomBlock.convolutional_Block(input= x, f= 3, filters= [256, 256, 1024], stage= 4, block= 'CB_', s= 2)
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [256, 256, 1024], stage= 4, block= 'IB_1')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [256, 256, 1024], stage= 4, block= 'IB_2')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [256, 256, 1024], stage= 4, block= 'IB_3')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [256, 256, 1024], stage= 4, block= 'IB_4')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [256, 256, 1024], stage= 4, block= 'IB_5')

    # Stage 5
    x = CustomBlock.convolutional_Block(input= x, f= 3, filters= [512, 512, 2048], stage= 5, block= 'CB_', s= 2)
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [512, 512, 2048], stage= 5, block= 'IB_1')
    x = CustomBlock.identity_Block(input= x, f= 3, filters= [512, 512, 2048], stage= 5, block= 'IB_2')

    # Average Pool
    x = AveragePooling2D(pool_size= (2,2), name= 'avg_pool')(x)

    # Output layer
    x = Flatten()(x)
    output = Dense(units= classes, activation= 'softmax', name= 'output', kernel_initializer= glorot_uniform(seed= 0))(x)

    model = Model(inputs = x_input, outputs= output, name= 'ResNet50')

    return model

# %%
model = CustomResNet.ResNet50(input_shape= (64, 64, 3), classes= 6)
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# custom_layer (CustomLayer)      (None, 32, 32, 64)   9728        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 15, 15, 64)   0           custom_layer[0][0]
# __________________________________________________________________________________________________
# custom_layer_1 (CustomLayer)    (None, 15, 15, 64)   4416        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# custom_layer_2 (CustomLayer)    (None, 15, 15, 64)   37184       custom_layer_1[0][0]
# __________________________________________________________________________________________________
# resCB_S21 (Conv2D)              (None, 15, 15, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# custom_layer_3 (CustomLayer)    (None, 15, 15, 256)  17664       custom_layer_2[0][0]
# __________________________________________________________________________________________________
# bnCB_S21 (BatchNormalization)   (None, 15, 15, 256)  1024        resCB_S21[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 15, 15, 256)  0           custom_layer_3[0][0]
#                                                                  bnCB_S21[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# custom_layer_4 (CustomLayer)    (None, 15, 15, 64)   16704       activation_4[0][0]
# __________________________________________________________________________________________________
# custom_layer_5 (CustomLayer)    (None, 15, 15, 64)   37184       custom_layer_4[0][0]
# __________________________________________________________________________________________________
# custom_layer_6 (CustomLayer)    (None, 15, 15, 256)  17664       custom_layer_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 15, 15, 256)  0           custom_layer_6[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 15, 15, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# custom_layer_7 (CustomLayer)    (None, 15, 15, 64)   16704       activation_8[0][0]
# __________________________________________________________________________________________________
# custom_layer_8 (CustomLayer)    (None, 15, 15, 64)   37184       custom_layer_7[0][0]
# __________________________________________________________________________________________________
# custom_layer_9 (CustomLayer)    (None, 15, 15, 256)  17664       custom_layer_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 15, 15, 256)  0           custom_layer_9[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 15, 15, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# custom_layer_10 (CustomLayer)   (None, 8, 8, 128)    33408       activation_12[0][0]
# __________________________________________________________________________________________________
# custom_layer_11 (CustomLayer)   (None, 8, 8, 128)    148096      custom_layer_10[0][0]
# __________________________________________________________________________________________________
# resCB_S31 (Conv2D)              (None, 8, 8, 512)    131584      activation_12[0][0]
# __________________________________________________________________________________________________
# custom_layer_12 (CustomLayer)   (None, 8, 8, 512)    68096       custom_layer_11[0][0]
# __________________________________________________________________________________________________
# bnCB_S31 (BatchNormalization)   (None, 8, 8, 512)    2048        resCB_S31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 512)    0           custom_layer_12[0][0]
#                                                                  bnCB_S31[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 512)    0           add_3[0][0]
# __________________________________________________________________________________________________
# custom_layer_13 (CustomLayer)   (None, 8, 8, 128)    66176       activation_16[0][0]
# __________________________________________________________________________________________________
# custom_layer_14 (CustomLayer)   (None, 8, 8, 128)    148096      custom_layer_13[0][0]
# __________________________________________________________________________________________________
# custom_layer_15 (CustomLayer)   (None, 8, 8, 512)    68096       custom_layer_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 512)    0           custom_layer_15[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# custom_layer_16 (CustomLayer)   (None, 8, 8, 128)    66176       activation_20[0][0]
# __________________________________________________________________________________________________
# custom_layer_17 (CustomLayer)   (None, 8, 8, 128)    148096      custom_layer_16[0][0]
# __________________________________________________________________________________________________
# custom_layer_18 (CustomLayer)   (None, 8, 8, 512)    68096       custom_layer_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 512)    0           custom_layer_18[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# custom_layer_19 (CustomLayer)   (None, 8, 8, 128)    66176       activation_24[0][0]
# __________________________________________________________________________________________________
# custom_layer_20 (CustomLayer)   (None, 8, 8, 128)    148096      custom_layer_19[0][0]
# __________________________________________________________________________________________________
# custom_layer_21 (CustomLayer)   (None, 8, 8, 512)    68096       custom_layer_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 512)    0           custom_layer_21[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# custom_layer_22 (CustomLayer)   (None, 4, 4, 256)    132352      activation_28[0][0]
# __________________________________________________________________________________________________
# custom_layer_23 (CustomLayer)   (None, 4, 4, 256)    591104      custom_layer_22[0][0]
# __________________________________________________________________________________________________
# resCB_S41 (Conv2D)              (None, 4, 4, 1024)   525312      activation_28[0][0]
# __________________________________________________________________________________________________
# custom_layer_24 (CustomLayer)   (None, 4, 4, 1024)   267264      custom_layer_23[0][0]
# __________________________________________________________________________________________________
# bnCB_S41 (BatchNormalization)   (None, 4, 4, 1024)   4096        resCB_S41[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 1024)   0           custom_layer_24[0][0]
#                                                                  bnCB_S41[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 1024)   0           add_7[0][0]
# __________________________________________________________________________________________________
# custom_layer_25 (CustomLayer)   (None, 4, 4, 256)    263424      activation_32[0][0]
# __________________________________________________________________________________________________
# custom_layer_26 (CustomLayer)   (None, 4, 4, 256)    591104      custom_layer_25[0][0]
# __________________________________________________________________________________________________
# custom_layer_27 (CustomLayer)   (None, 4, 4, 1024)   267264      custom_layer_26[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 1024)   0           custom_layer_27[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 4, 4, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# custom_layer_28 (CustomLayer)   (None, 4, 4, 256)    263424      activation_36[0][0]
# __________________________________________________________________________________________________
# custom_layer_29 (CustomLayer)   (None, 4, 4, 256)    591104      custom_layer_28[0][0]
# __________________________________________________________________________________________________
# custom_layer_30 (CustomLayer)   (None, 4, 4, 1024)   267264      custom_layer_29[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 1024)   0           custom_layer_30[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 4, 4, 1024)   0           add_9[0][0]
# __________________________________________________________________________________________________
# custom_layer_31 (CustomLayer)   (None, 4, 4, 256)    263424      activation_40[0][0]
# __________________________________________________________________________________________________
# custom_layer_32 (CustomLayer)   (None, 4, 4, 256)    591104      custom_layer_31[0][0]
# __________________________________________________________________________________________________
# custom_layer_33 (CustomLayer)   (None, 4, 4, 1024)   267264      custom_layer_32[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 1024)   0           custom_layer_33[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 1024)   0           add_10[0][0]
# __________________________________________________________________________________________________
# custom_layer_34 (CustomLayer)   (None, 4, 4, 256)    263424      activation_44[0][0]
# __________________________________________________________________________________________________
# custom_layer_35 (CustomLayer)   (None, 4, 4, 256)    591104      custom_layer_34[0][0]
# __________________________________________________________________________________________________
# custom_layer_36 (CustomLayer)   (None, 4, 4, 1024)   267264      custom_layer_35[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 1024)   0           custom_layer_36[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# custom_layer_37 (CustomLayer)   (None, 4, 4, 256)    263424      activation_48[0][0]
# __________________________________________________________________________________________________
# custom_layer_38 (CustomLayer)   (None, 4, 4, 256)    591104      custom_layer_37[0][0]
# __________________________________________________________________________________________________
# custom_layer_39 (CustomLayer)   (None, 4, 4, 1024)   267264      custom_layer_38[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 1024)   0           custom_layer_39[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 4, 4, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# custom_layer_40 (CustomLayer)   (None, 2, 2, 512)    526848      activation_52[0][0]
# __________________________________________________________________________________________________
# custom_layer_41 (CustomLayer)   (None, 2, 2, 512)    2361856     custom_layer_40[0][0]
# __________________________________________________________________________________________________
# resCB_S51 (Conv2D)              (None, 2, 2, 2048)   2099200     activation_52[0][0]
# __________________________________________________________________________________________________
# custom_layer_42 (CustomLayer)   (None, 2, 2, 2048)   1058816     custom_layer_41[0][0]
# __________________________________________________________________________________________________
# bnCB_S51 (BatchNormalization)   (None, 2, 2, 2048)   8192        resCB_S51[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2, 2, 2048)   0           custom_layer_42[0][0]
#                                                                  bnCB_S51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 2, 2, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# custom_layer_43 (CustomLayer)   (None, 2, 2, 512)    1051136     activation_56[0][0]
# __________________________________________________________________________________________________
# custom_layer_44 (CustomLayer)   (None, 2, 2, 512)    2361856     custom_layer_43[0][0]
# __________________________________________________________________________________________________
# custom_layer_45 (CustomLayer)   (None, 2, 2, 2048)   1058816     custom_layer_44[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 2048)   0           custom_layer_45[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 2, 2, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# custom_layer_46 (CustomLayer)   (None, 2, 2, 512)    1051136     activation_60[0][0]
# __________________________________________________________________________________________________
# custom_layer_47 (CustomLayer)   (None, 2, 2, 512)    2361856     custom_layer_46[0][0]
# __________________________________________________________________________________________________
# custom_layer_48 (CustomLayer)   (None, 2, 2, 2048)   1058816     custom_layer_47[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 2048)   0           custom_layer_48[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 2, 2, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_64[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 6)            12294       flatten[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,546,886
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
